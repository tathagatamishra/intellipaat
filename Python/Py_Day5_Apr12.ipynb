# %% [markdown]
# # PYTHON BASICS - Day 5

# %%
numArr = [1, 2, 3, 4, 5]

#insert

# add element at a specific index

numArr.insert(1, 69)

# %%
# remove element from list

numArr.remove(4)

# %%
1+1
