# %% [markdown]
# # Introduction to Machine Learning

# %% [markdown]
# <https://drive.google.com/drive/u/0/folders/1lxeQ0-w9hndodUrHxlxF5u0EszqIkd3l>
#
# <https://dsaiwithshikhar.substack.com/p/machine-learning-series-day-1-introduction>

# %% [markdown]
# <img src="CRISP-DM_Process_Diagram.png" width="480">

# %% [markdown]
# ## The ML Workflow:
#
# - Step 1: Define the Business Problem
# - Step 2: Collect & Prepare Data
# - Step 3: Exploratory Data Analysis (EDA)
# - ml start from step 4
# - Step 4: Feature Engineering
# - Step 5: Train the Model
# - Step 6: Evaluate the Model
# - Step 7: Deploy & Monitor
